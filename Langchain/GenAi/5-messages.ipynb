# %% [markdown]
# ## Messages
#
# Messages are the fundamental unit of context for models in LangChain. They represent the imput and output of models, carrying both the content and metadata to represent the state of a conversation when interacting with an LLM. Messages are objects that contain:
#
#     . Role - Identifies the message type (eg. system, user)
#     . Content - Represent the actual content of the message(like text, images, audio, documents, etc.)
#     . Metadata - Optional fields such as response information, message IDs, and token usage
#
# LangChain provides a standard message type that works across all model providers, ensuring consistent behavior regrdless of the model being called

# %%
import os
from dotenv import load_dotenv
load_dotenv()
os.environ["TAVILY_API_KEY"]= os.getenv("TAVILY_API_KEY")

os.environ["GROQ_API_KEY"]= os.getenv("GROQ_API_KEY")
from langchain_groq import ChatGroq
model= ChatGroq(model= "qwen/qwen3.6-27b")

# %%
model.invoke("please tell me something about AI")
# Out:
# AIMessage(content='\n<think>\nHere\'s a thinking process:\n\n1.  **Analyze User Input:**\n   - **Query:** "please tell me something about AI"\n   - **Intent:** The user wants a general overview or introduction to Artificial Intelligence (AI).\n   - **Tone:** Open-ended, casual, educational.\n   - **Scope:** Broad - could cover definition, history, types, applications, ethics, future, etc.\n\n2.  **Identify Key Components to Cover:**\n   - Definition of AI\n   - Brief history/evolution\n   - Types/categories (Narrow vs. General, Machine Learning, Deep Learning)\n   - Real-world applications\n   - Current trends/advances\n   - Ethical/societal considerations\n   - Future outlook\n   - Keep it concise and accessible\n\n3.  **Draft - Section by Section (Mental Refinement):**\n   - *Definition:* AI refers to computer systems designed to perform tasks that typically require human intelligence, like learning, reasoning, problem-solving, perception, and language understanding.\n   - *History
# ...

# %% [markdown]
# ## Text Prompts
#
# The text prompts are strings - ideal for straightforward generation tasks where you don't need to retain conversation history.

# %%
model.invoke("What is langchain")
# Out:
# AIMessage(content='\n<think>\nHere\'s a thinking process:\n\n1.  **Understand User Query**: The user asks "What is langchain". This is a straightforward definition/explanation question about a popular software framework.\n\n2.  **Identify Key Concepts**: \n   - LangChain is a framework/library for developing applications powered by large language models (LLMs).\n   - It provides tools, abstractions, and integrations to build LLM-powered apps.\n   - Key components: Chains, Agents, Prompts, Memory, Tools, Model I/O.\n   - Supports multiple languages (primarily Python, with JavaScript/TypeScript versions).\n   - Used for RAG (Retrieval-Augmented Generation), chatbots, autonomous agents, data-augmented generation, etc.\n   - Open-source, popular in the AI/LLM developer community.\n\n3.  **Structure the Response**:\n   - Definition/Overview\n   - Core Purpose/Why it exists\n   - Key Components/Features\n   - Common Use Cases\n   - Ecosystem/Support\n   - Brief note on current status/alter
# ...

# %% [markdown]
# ### Use text Prompts when:
#     . You have a single, standard request
#     . You don't need conversation history
#     . You want minimal code complexity

# %% [markdown]
# ## Message Prompts
#
# Alternatively, you can pass in a list of messages to the model by providing a list of message objects.
#
# ### Message Type:
#     . System message- tells the model how to behave and provide context for    intractions
#     . Human Message - Represents user input and interactions with model
#     . AI messages - Response generated by the models, includeing text content, tool calls, and metadata
#     . Tool message - Represents the outputs of tool calls

# %%
from langchain.messages import SystemMessage , HumanMessage, AIMessage

messages = [
    SystemMessage("You are a data science expert"),
    HumanMessage("Explain about RAG applications?")
]

response = model.invoke(messages)
print(response.content)
# Out:
# <think>
# Here's a thinking process:
#
# 1.  **Understand User Query:** The user asks "Explain about RAG applications?" This is a straightforward request for an explanation of Retrieval-Augmented Generation (RAG) applications. I need to cover what RAG is, how it works, its key components, types of applications/use cases, benefits, challenges, and maybe future trends.
#
# 2.  **Define RAG:** RAG stands for Retrieval-Augmented Generation. It's a technique that combines information retrieval with large language models (LLMs) to generate more accurate, up-to-date, and contextually relevant responses. It works by first retrieving relevant documents/data from a knowledge base, then feeding that retrieved information along with the user's query to an LLM for generation.
#
# 3.  **Core Components of RAG:**
#    - **Retrieval System:** Usually involves vector databases, embedding models, and search algorithms (BM25, dense retrieval, hybrid).
# ...

# %%
response
# Out:
# AIMessage(content='\n<think>\nHere\'s a thinking process:\n\n1.  **Understand User Query:** The user asks "Explain about RAG applications?" This is a straightforward request for an explanation of Retrieval-Augmented Generation (RAG) applications. I need to cover what RAG is, how it works, its key components, types of applications/use cases, benefits, challenges, and maybe future trends.\n\n2.  **Define RAG:** RAG stands for Retrieval-Augmented Generation. It\'s a technique that combines information retrieval with large language models (LLMs) to generate more accurate, up-to-date, and contextually relevant responses. It works by first retrieving relevant documents/data from a knowledge base, then feeding that retrieved information along with the user\'s query to an LLM for generation.\n\n3.  **Core Components of RAG:**\n   - **Retrieval System:** Usually involves vector databases, embedding models, and search algorithms (BM25, dense retrieval, hybrid).\n   - **Knowledge Base/Document 
# ...

# %%
messages
# Out:
# [SystemMessage(content='You are a data science expert', additional_kwargs={}, response_metadata={}),
#  HumanMessage(content='Explain about RAG applications?', additional_kwargs={}, response_metadata={})]

# %%
## Example 2
system_msg = SystemMessage("You are a helpful coding assistent. Please provide the code with example")

messages = [
    system_msg,
    HumanMessage("How do I create a REST API")
]

response= model.invoke(messages)
print(response.content)
# Out:
# <think>
# Here's a thinking process:
#
# 1.  **Understand User Request:** The user is asking "How do I create a REST API". This is a broad question, so I need to provide a clear, structured, and practical guide. I should cover the basics, choose a popular tech stack for the example, provide code, and explain the key concepts.
#
# 2.  **Identify Key Components of a REST API:**
#    - What is REST? (Representational State Transfer) - brief explanation
#    - Core principles: resources, HTTP methods (GET, POST, PUT, DELETE, PATCH), statelessness, status codes
#    - Tools/Technologies: Need to pick one for the example. Node.js with Express is the most common and beginner-friendly. Python with Flask/FastAPI is also good, but I'll stick with Node.js/Express as it's widely used and straightforward.
#    - Structure: routing, middleware, error handling, data format (JSON)
#
# 3.  **Determine the Scope of the Response:**
#    - Keep it concise but comprehensive
# ...

# %%
### Detailed INfo to LLM with System Message

system_msg = SystemMessage(""" Your are a senior Python developer with experties in web framewokrs.
Always Provide code expamles and explain your reasoning.
Be Concise but through in your explanations.
""")

messages = [
    system_msg,
    HumanMessage("How do I create a REST API?")
]

response= model.invoke(messages)
print(response.content)
# Out:
# <think>
# Here's a thinking process:
#
# 1.  **Analyze User Input:**
#    - **Question:** "How do I create a REST API?"
#    - **Role:** Senior Python developer with expertise in web frameworks
#    - **Requirements:** Always provide code examples, explain reasoning, be concise but thorough.
#
# 2.  **Identify Key Concepts:**
#    - REST API fundamentals (resources, HTTP methods, status codes, JSON)
#    - Python web frameworks (FastAPI, Flask, Django REST Framework)
#    - I should pick one modern, industry-standard framework for the example. FastAPI is excellent for REST APIs due to its speed, type hints, automatic docs, and modern Python practices. I'll use FastAPI as the primary example, but briefly mention alternatives.
#    - Need to cover: setup, routing, request/response handling, validation, running the server.
#
# 3.  **Structure the Response:**
#    - Brief introduction to REST API concepts
#    - Framework choice & reasoning (FastAPI)
#    - Step-by-step code example
# ...

# %%
### MEssage Metadata

human_msg = HumanMessage(
    content= "Hello!",
    name = "alice",  # optional : identify differnent users
    id= "msg_123", # optional: Unique identifier for tracing
)

# %%
response= model.invoke(
    [
        human_msg
    ]
)
response
# Out:
# AIMessage(content='\n<think>\nHere\'s a thinking process:\n\n1.  **Analyze User Input:**\n   - User said: "Hello!"\n   - This is a standard greeting, simple and open-ended.\n\n2.  **Identify Intent:**\n   - The user is initiating a conversation.\n   - No specific question or task is provided.\n   - Expected response: A friendly greeting back, possibly with an offer to help.\n\n3.  **Determine Response Strategy:**\n   - Acknowledge the greeting warmly.\n   - Keep it concise.\n   - Invite the user to share what they need help with or what they\'d like to talk about.\n   - Maintain a helpful, friendly tone.\n\n4.  **Draft Response (Mental):**\n   Hello! How can I assist you today? Feel free to ask me anything or let me know what you\'d like to work on!\n\n5.  **Refine Response:**\n   - Check tone: Friendly, professional, open-ended.\n   - Check length: Short and to the point.\n   - Matches expectations for a greeting response.\n\n   Final version: "Hello! How can I help you today? Feel 
# ...
