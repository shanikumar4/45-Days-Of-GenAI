# %% [markdown]
# ### Langchain Version V1

# %%
import langchain
print(langchain.__version__)
# Out:
# 1.3.14

# %%
import os
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %% [markdown]
# ### LLM Model Integration With Google Gemini

# %%
os.environ["GOOGLE_API_KEY"]= os.getenv("GEMINI_API_KEY")

# %%
from langchain.chat_models import init_chat_model
model = init_chat_model("google_genai:gemini-3.5-flash")
response= model.invoke("Write me an essay about Artificial Intellignece")
print(response.content)

# %%
from langchain_google_genai import ChatGoogleGenerativeAI
model=ChatGoogleGenerativeAI(model="gemini-3.5-flash")
response= model.invoke("Write me an essay about Artificial Intellignece")
print(response.content)

# %% [markdown]
# ### LLM Model Integration With Groq API

# %%
import os
from langchain.chat_models import init_chat_model
os.environ["GROQ_API_KEY"]=os.getenv("GROQ_API_KEY")

# model = init_chat_model("groq:llama-3.1-8b-instant")
# response= model.invoke("Write me a joke on machine learning algorithms")
# print(response.content)

# %%
import os 
from langchain_groq import ChatGroq

model= ChatGroq(model="qwen/qwen3.6-27b")
response = model.invoke("Why do parrots talk?")
print(response.content)
# Out:
# <think>
# Here's a thinking process:
#
# 1.  **Understand User Question**: The user asks "Why do parrots talk?" This is a common question about animal behavior, specifically parrot vocalization and speech mimicry.
#
# 2.  **Identify Key Concepts**:
#    - Parrots don't actually "talk" in the human sense (they don't understand language semantically like humans do)
#    - They mimic sounds, including human speech
#    - Evolutionary/biological reasons for this behavior
#    - Social bonding, communication within flocks
#    - Brain structure (vocal learning centers)
#    - Environmental adaptation
#
# 3.  **Scientific Explanation**:
#    - **Vocal Learning**: Parrots are vocal learners, meaning they can acquire new sounds through exposure and practice, unlike most birds that are genetically programmed for specific songs.
# ...

# %% [markdown]
# ### Streaming And Batch

# %% [markdown]
# ### Streaming
# most models can stream their output content while it is being generated. By displaying progressively, streaming significantly improves user experience, particuarly for longer responses. Calling Stream() returns an iterator that yields output chunks as they are produced. You can use a loop to process each chunk in real time.

# %%
model.invoke("write me a 500 words paragraph on AI")
# Out:
# AIMessage(content='\n<think>\nHere\'s a thinking process:\n\n1.  **Analyze User Request:**\n   - **Topic:** AI (Artificial Intelligence)\n   - **Length:** 500 words\n   - **Format:** Single paragraph\n   - **Goal:** Write a comprehensive, coherent, and engaging paragraph about AI\n\n2.  **Deconstruct Requirements:**\n   - Must be exactly or approximately 500 words\n   - Must be a single paragraph (no line breaks, no subheadings)\n   - Should cover key aspects of AI: definition, history/evolution, capabilities, applications, ethical concerns, future implications\n   - Maintain flow and coherence throughout the single paragraph\n\n3.  **Brainstorming Content (Mental Outline):**\n   - Introduction: Define AI, its core premise (machines mimicking human intelligence)\n   - Historical context: From early rule-based systems to modern machine learning/deep learning\n   - Current capabilities: Pattern recognition, natural language processing, decision-making, automation\n   - Applications: He
# ...

# %%
for chunk in model.stream("write me a 500 words paragraph on AI"):
    print(chunk.text, end="", flush=True)
# Out:
# <think>
# Here's a thinking thinking sequence
#
# 1.  **Deconstruct the user:**
#     *   Topic: AI (Artificial Intelligence).
#     *   Length: 500 words.
#     *   Format: A single paragraph.
#
# 2.  **Initial analysis and planning:**
#     *   *Challenge:* Writing a 500-word single paragraph is difficult. It risks becoming a "wall of text" that's hard to read. However, the user explicitly asked for a "paragraph," so I must adhere to that constraint. I need to ensure flow and cohesion to keep the reader engaged despite the length.
#     *   *Content Strategy:* To fill 500 words meaningfully without fluff, I need to cover multiple facets of AI: definition, history/evolution, current applications, benefits, ethical concerns, future outlook, and a concluding thought.
#     *   *Structure within the paragraph:* I'll use transition words and phrases to guide the reader through these sub-topics smoothly.
#         *   *Intro:* What is AI? Machine learning, neural networks.
# ...

# %%
for chunk in model.stream("Why do parrots have colorful feathers?"):
    print(chunk.text, end="", flush=True)
# Out:
# <think>
# Here's a thinking process:
#
# 1.  **Understand User Question**: The user asks "Why do parrots have colorful feathers?" This is a biological/evolutionary question about parrot plumage coloration.
#
# 2.  **Identify Key Concepts**:
#    - Evolutionary biology
#    - Natural selection vs. sexual selection
#    - Functions of coloration in birds
#    - Parrot-specific adaptations
#    - Pigments vs. structural coloration
#    - Communication, camouflage, species recognition, thermoregulation, health indicators
#
# 3.  **Brainstorming/Research Knowledge**:
#    - Parrots are known for bright colors: red, blue, green, yellow, etc.
#    - Two main types of bird feather coloration: pigment-based (melanin, carotenoids, psittacofulvins) and structural (light scattering/refraction).
#    - Functions of bright colors in parrots:
#      * Sexual selection/female choice
#      * Species recognition (important in dense habitats)
#      * Social signaling/status within flocks
# ...

# %% [markdown]
# ### Batch
# Batching a collection of independent requests to model can significantly improve performance and reduce cost, as processing can be done in parallel:

# %%
responses = model.batch(
    [
        "why do parrots have colorful feathers?",
        "How do airplanes fly?",
        "What is quantum computing?" ],
        config={
            'max_concurrency': 5 # Limit to 5 parallel calls
        }

)

for response in responses: 
    print(response)
# Out:
# content='\n<think>\nHere\'s a thinking process:\n\n1.  **Understand User Question**: The user asks "why do parrots have colorful feathers?" This is a biological/evolutionary question about parrot plumage coloration.\n\n2.  **Identify Key Concepts**: \n   - Parrot feather coloration\n   - Evolutionary reasons for bright colors in birds\n   - Functions of coloration: camouflage, mating, communication, social signaling, species recognition, mimicry/environmental adaptation\n   - Biological mechanisms: pigments (carotenoids, porphyrins), structural coloration\n   - Ecological context: tropical habitats, forest environments\n\n3.  **Research/Verify Facts** (Internal Knowledge):\n   - Parrots are known for vibrant colors (red, blue, green, yellow)\n   - Primary evolutionary drivers: sexual selection (mate choice), social communication, species recognition, and sometimes camouflage (green feathers blend with foliage)\n   - Color production: \n     - Pigments: carotenoids (diet-derived, reds
# ...
