# %% [markdown]
# ### Langchain Version V1

# %%
import langchain
print(langchain.__version__)
# Out:
# 1.3.14

# %%
import os
from dotenv import load_dotenv
load_dotenv()

os.environ["GROQ_API_KEY"]=os.getenv("GROQ_API_KEY")

# %% [markdown]
# ### Generative AI Application with Groq

# %%
from langchain.chat_models import init_chat_model
model= init_chat_model("")

# %% [markdown]
# ### LLM Model Integration With Google Gemini

# %%
os.environ["GOOGLE_API_KEY"]= os.getenv("GEMINI_API_KEY")

# %%
from langchain.chat_models import init_chat_model
model = init_chat_model("google_genai:gemini-3.5-flash")
response= model.invoke("Write me an essay about Artificial Intellignece")
print(response.content)
# Out:
# Both GOOGLE_API_KEY and GEMINI_API_KEY are set. Using GOOGLE_API_KEY.
# [{'type': 'text', 'text': '**Title:** The Promise and Peril of the Algorithmic Age: An Exploration of Artificial Intelligence\n\nOnce confined to the realms of science fiction, Artificial Intelligence (AI) has rapidly transitioned into the defining technology of the twenty-first century. From the algorithms that curate our social media feeds to the generative tools writing poetry and code, AI is no longer a futuristic concept—it is an active partner in human daily life. Broadly defined as the simulation of human intelligence processes by machines, AI represents a paradigm shift in how we process information, solve problems, and interact with the world. However, this technological revolution is a double-edged sword. While AI holds the potential to solve some of humanity\'s most complex challenges, it also introduces unprecedented ethical, economic, and existential risks that demand proactive governance.\n\nTo understand the current state of AI, it is essential to distinguish between its different forms. The AI we interact with today is known as Artificial Narrow Intelligence (ANI). These systems are designed to perform specific tasks, such as translating languages, driving cars, or diagnosing medical conditions. They operate within a set of pre-defined parameters and, despite their complexity, do not possess consciousness or genuine understanding. The theoretical next stage is Artificial General Intelligence (AGI)—machines that possess the ability to understand, learn, and apply knowledge across a broad range of tasks at a human level. While AGI remains a distant and highly debated milestone, the rapid advancement of current ANI systems is already fundamentally altering global industries.\n\nThe benefits of AI are most visible in its capacity to enhance human productivity and solve previously intractable problems. In healthcare, AI is revolutionized diagnostics and drug discovery. Machine learning models can analyze medical imaging with accuracy rates that rival or exceed human radiologists, enabling early detection of diseases like cancer. Furthermore, AI has accelerated the process of drug discovery from decades to mere months by predicting how proteins fold, as demonstrated by DeepMind’s AlphaFold. Beyond medicine, AI is a powerful tool in combatting climate change. It is used to optimize energy grids, predict extreme weather patterns, and model climate scenarios with high precision. By automating repetitive and dangerous tasks, AI also frees humans to focus on creative, strategic, and empathetic endeavors.\n\nHowever, the rapid integration of AI into society brings significant challenges, chief among them being economic disruption. The automation of cognitive and manual labor threatens to displace millions of workers. While technology has historically created more jobs than it destroyed, the speed and scale of the AI revolution may outpace the workforce\'s ability to reskill, leading to increased economic inequality. \n\nMoreover, AI systems are not inherently neutral; they learn from data generated by humans. This presents a severe risk of algorithmic bias. If historical data contains racial, gender, or socioeconomic prejudices, the AI will inherit and amplify these biases. This is already evident in biased hiring algorithms, facial recognition software that misidentifies minorities, and predictive policing tools that unfairly target marginalized communities. \n\nBeyond bias, the rise of "deepfakes" and generative AI tools has blurred the line between reality and fabrication. The ease with which realistic fake audio, video, and text can be produced poses a direct threat to democratic processes, making it easier than ever to spread disinformation and manipulate public opinion. Furthermore, the "black box" nature of complex neural networks—where even their creators cannot fully explain how a system arrived at a specific decision—creates accountability gaps in high-stakes fields like justice, finance, and warfare.\n\nNavigati ...

# %%
from langchain_google_genai import ChatGoogleGenerativeAI
model=ChatGoogleGenerativeAI(model="gemini-3.5-flash")
response= model.invoke("Write me an essay about Artificial Intellignece")
print(response.content)
# Out:
# Both GOOGLE_API_KEY and GEMINI_API_KEY are set. Using GOOGLE_API_KEY.
# [{'type': 'text', 'text': '**Title:** The Promise and Peril of the Silicon Mind: Navigating the Era of Artificial Intelligence\n\nIn the span of just a few decades, Artificial Intelligence (AI) has transitioned from the imaginative realms of science fiction to the foundational fabric of daily life. Today, AI influences the music we listen to, diagnoses complex medical conditions, drives cars, and writes poetry. Defined broadly as the capability of a machine to imitate intelligent human behavior, AI is not merely a technological trend; it is a profound paradigm shift. As humanity stands on the cusp of this algorithmic revolution, it is increasingly clear that AI is a double-edged sword. While it holds the promise of solving some of our species\' most intractable problems, it also presents unprecedented ethical, economic, and existential challenges.\n\nTo understand the current state of AI, it is helpful to distinguish between its two primary forms: Narrow AI and General AI. Narrow AI, or "Weak AI," is what exists today. These are systems designed to perform specific tasks—such as facial recognition, language translation, or playing chess—often with superhuman efficiency. Conversely, Artificial General Intelligence (AGI), or "Strong AI," refers to a hypothetical machine that possesses the ability to understand, learn, and apply knowledge across any intellectual task, much like a human being. While AGI remains a distant and debated milestone, the rapid advancement of Narrow AI—particularly through machine learning and deep neural networks—has already begun to reshape global infrastructure.\n\nThe benefits of AI are already visible across various sectors, most notably in healthcare. By analyzing vast datasets at speeds impossible for humans, AI algorithms can detect diseases like cancer in their earliest stages, discover new drug compounds, and personalize patient treatment plans. In environmental science, AI is used to model climate change patterns, optimize renewable energy grids, and track deforestation. Furthermore, in the workplace, AI automates mundane, repetitive tasks, freeing humans to engage in more creative, strategic, and empathetic endeavors. From boosting agricultural yields to managing complex logistics, AI acts as a cognitive magnifier, amplifying human capability to tackle global challenges.\n\nHowever, this technological leap is accompanied by profound societal risks. Chief among these is the economic disruption caused by automation. While technology has historically created more jobs than it destroyed, the speed and cognitive nature of AI-driven automation threaten to displace workers at a rate that society may struggle to absorb. Both blue-collar and white-collar professions—from truck drivers to financial analysts—face significant disruption, raising urgent questions about wealth inequality and the necessity of universal basic income or robust retraining programs.\n\nBeyond economics, AI poses severe ethical dilemmas, particularly regarding bias and privacy. AI systems learn from historical human data. If that data contains societal biases, the AI will inevitably learn, codify, and scale those biases. This has already been observed in flawed facial recognition software used by law enforcement and biased hiring algorithms. Moreover, the rise of "deepfakes" (highly realistic manipulated videos and audio) and AI-driven misinformation campaigns threatens the very foundation of democratic discourse, making it increasingly difficult to distinguish truth from fabrication in the digital age.\n\nFinally, there is the existential question of control and alignment. As AI systems become more autonomous and complex, ensuring that their goals align with human values becomes a matter of survival. This is known as the "alignment problem." If a highly capable AI system is given a poorly defined goal, it may pursue that goal in ways that are harmful to humanity. This is not a matter of machines becoming "evil," but rather of th ...
