# %%
from helper import ask_gpt

print(ask_gpt("Say only: Hello"))
# Out:
# Hello

# %% [markdown]
# Task 01: Sentiment Analysis

# %%
with open("prompts/sentiment.txt", "r") as file:
    prompt = file.read()

response = ask_gpt(prompt)

print(response)
# Out:
# Positive

# %% [markdown]
# Task 02: Summarization

# %%
with open("prompts/summarize.txt") as file:
    prompt = file.read()

print(ask_gpt(prompt))
# Out:
# - **Enhanced Diagnostics**: AI technologies are improving diagnostic accuracy by analyzing medical data and identifying patterns that may be missed by human clinicians, leading to earlier and more precise disease detection.
#
# - **Personalized Treatment Plans**: AI enables the development of tailored treatment plans for patients by analyzing individual health data, genetics, and treatment responses, thus optimizing therapeutic outcomes.
#
# - **Operational Efficiency**: AI streamlines administrative processes in healthcare settings, reducing costs and improving workflow efficiency, allowing healthcare providers to focus more on patient care.

# %% [markdown]
# Task 03: Translation

# %%
with open("prompts/translation.txt") as file:
    prompt = file.read()

print(ask_gpt(prompt))
# Out:
# "मुझे आर्टिफिशियल इंटेलिजेंस सीखना पसंद है। और जनरेटिव एआई तकनीक का भविष्य होगा।"

# %% [markdown]
# Task 04: Grammar Correction

# %%
with open("prompts/grammerCorrection.txt") as file:
    prompt = file.read()

print(ask_gpt(prompt))
# Out:
# Yesterday I went to the market with my friends because we wanted to buy some fruits and snacks. The weather was very hot, but we enjoyed walking together. There were many people in the market, and everyone was buying something. My friend didn't have enough money, so I lent him some cash. After that, we ate at a small restaurant where the food tasted very delicious. I was feeling happy because it had been a long time since we met each other. When we were returning home, it started raining suddenly, and we got completely wet. Although we were tired, we laughed a lot and made many good memories. It was one of the best days of my life.

# %% [markdown]
# Task 05: Named Entity Recognition

# %%
with open("prompts/recogination.txt") as file:
    prompt = file.read()

print(ask_gpt(prompt))
# Out:
# **Person:** Satya Nadella
# **Organization:** Microsoft
# **Location:** Bengaluru
# **Text:** Satya Nadella visited Bengaluru to meet Microsoft engineers.

# %% [markdown]
# Task 06: Keyword Extraction

# %%
with open("prompts/extraction.txt") as file:
    prompt = file.read()

print(ask_gpt(prompt))
# Out:
# 1. Large Language Models
# 2. Revolutionizing
# 3. Software
# 4. Engineering
# 5. Technology

# %% [markdown]
# Task 07: Text Classification

# %%
with open("prompts/classification.txt") as file:
    prompt = file.read()

print(ask_gpt(prompt))
# Out:
# Label: Life

# %% [markdown]
# Task 08: Question Answering

# %%
with open("prompts/QuestionAndAns.txt") as file:
    prompt = file.read()

print(ask_gpt(prompt))
# Out:
# Two benefits of the Internet are the ability to access information instantly and the capability to connect with others around the world.

# %% [markdown]
# Task 09: Email Writing

# %%
with open("prompts/emailWriting.txt") as file:
    prompt = file.read()

print(ask_gpt(prompt))
# Out:
# Subject: Leave Request for Medical Emergency
#
# Dear [Manager's Name],
#
# I hope this message finds you well. I am writing to formally request a leave of absence due to a medical emergency that requires my immediate attention.
#
# I anticipate needing [number of days] days off, starting from [start date] to [end date]. I will ensure that all my responsibilities are managed and will do my best to hand over my current projects to a colleague to minimize any disruption during my absence.
#
# Please let me know if there's any further information you need or if there are forms I should complete for this leave request. I appreciate your understanding during this difficult time.
#
# Thank you for your support.
#
# Best regards,
#
# [Your Name]
# [Your Job Title]
# [Your Contact Information]

# %% [markdown]
# Task 10: Information Extraction

# %%
with open("prompts/information.txt") as file:
    prompt = file.read()

print(ask_gpt(prompt))
# Out:
# ```json
# {
#   "Name": "Shani Kumar",
#   "Invoice Number": "INV-2026-1045",
#   "Date": "July 7, 2026",
#   "Amount": "â‚¹12,450.00"
# }
# ```
